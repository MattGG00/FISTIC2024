# %% [markdown]
# ## Esercizio Classificazione NLP1

# %%
import numpy as np
import pandas as pd
from skimpy import skim
from wordcloud import WordCloud, STOPWORDS

import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/NLPes1.csv')

# %%
# STEP1 DEFINIRE ED APPLICARE LA REGEX
df
# Out:
#                                                   text  class
# 0    b'insane ( but inspired ) musical about alferd...      1
# 1    b'written by david j . schow and john shirley ...      0
# 2    b'miramax " disinvited " on-line media from pr...      0
# 3    b'in " the astronaut\'s wife , " charlize ther...      0
# 4    b'one of the 90s\' most unwelcome thriller tre...      0
# ..                                                 ...    ...
# 408  b'hav plenty , as we are told in the beginning...      0
# 409  b'brian de palma\'s snake eyes stars nicolas c...      0
# 410  b'contact ( pg ) there\'s a moment late in rob...      1
# 411  b"this is a film that i was inclined to like a...      0
# 412  b'any remake of an alfred hitchcock film is at...      0
#
# [413 rows x 2 columns]

# %%
df['text'][1]
# Out:
# 'b\'written by david j . schow and john shirley , based on the comic book series and comic book strip by james o\\\'barr . \\ncast brandon lee , ernie hudson , michael wincott , david patrick kelly , rochelle davis , and jon polito . \\nmpaa rating " r " ( presumably for rape , language , and violence ) \\nrunning time 100 minutes \\n " looks like he zigged when he should\\\'ve zagged . " \\n- ernie hudson , as a police officer commenting on a suspicious death . \\ncomic book translations are notorious tricky-- anyone up for a double-bill of the punisher and captain america ? -- and the crow proves no exception . \\ndespite a gross of good intentions , brandon lee\\\'s final film doesn\\\'t fly very high . \\nthe story opens on halloween eve , better known as devil\\\'s night . \\nwilmington-as-detroit is in flames and the police are tending to at least * one * murder : young rock-musician-turned-pavement-artist eric draven ( lee ) , found on a sidewalk six-stories below the apartmen
# ...

# %%
def clean_movie_review(df):
    # Basic cleaning
    text = clean_review_text(df['text'])
    
    # Remove cast and crew information
    text = re.sub(r'written by.*?\\.', '', text)
    text = re.sub(r'cast.*?\\.', '', text)
    
    # Remove ratings and runtime
    text = re.sub(r'mpaa rating.*?minutes', '', text)
    
    # Remove quoted dialogue
    text = re.sub(r'"[^"]*"', '', text)
    
    # Clean up any resulting double spaces or periods
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'\.{2,}', '.', text)
    
    return text.strip()

# %%
## STEP 2 : EDA con WORDCLOUD
df['text']
# Out:
# 0      b'insane ( but inspired ) musical about alferd...
# 1      b'written by david j . schow and john shirley ...
# 2      b'miramax " disinvited " on-line media from pr...
# 3      b'in " the astronaut\'s wife , " charlize ther...
# 4      b'one of the 90s\' most unwelcome thriller tre...
#                              ...
# 408    b'hav plenty , as we are told in the beginning...
# 409    b'brian de palma\'s snake eyes stars nicolas c...
# 410    b'contact ( pg ) there\'s a moment late in rob...
# 411    b"this is a film that i was inclined to like a...
# 412    b'any remake of an alfred hitchcock film is at...
# Name: text, Length: 413, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    413 non-null    object
#  1   class   413 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 6.6+ KB

# %%
text = df['text'][1]
text
# Out:
# 'b\'written by david j . schow and john shirley , based on the comic book series and comic book strip by james o\\\'barr . \\ncast brandon lee , ernie hudson , michael wincott , david patrick kelly , rochelle davis , and jon polito . \\nmpaa rating " r " ( presumably for rape , language , and violence ) \\nrunning time 100 minutes \\n " looks like he zigged when he should\\\'ve zagged . " \\n- ernie hudson , as a police officer commenting on a suspicious death . \\ncomic book translations are notorious tricky-- anyone up for a double-bill of the punisher and captain america ? -- and the crow proves no exception . \\ndespite a gross of good intentions , brandon lee\\\'s final film doesn\\\'t fly very high . \\nthe story opens on halloween eve , better known as devil\\\'s night . \\nwilmington-as-detroit is in flames and the police are tending to at least * one * murder : young rock-musician-turned-pavement-artist eric draven ( lee ) , found on a sidewalk six-stories below the apartmen
# ...

# %%
wordcloud = WordCloud()
print(wordcloud)

# %%
wordcloud.generate(text)

# %%
import matplotlib.pyplot as plt

# %%
# word cloud only first row

plt.figure(figsize=(18,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
##STEP 3: Definizre X e y (features testuali e Target)

# %%
##STEP 4: Vettorizzazione - Bag of Words

# %%
##STEP 5: TF-IDF

# %%
##STEP 6: Split Training and Test

# %%
##STEP 7: Modellazione

# %%
# Step 8: Pipeline Finale (nuovo train test split su dati raw tetuali)
