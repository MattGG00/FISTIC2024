# %%
import pandas as pd
import numpy as np
from summarytools import dfSummary
import seaborn as sns
import matplotlib as plt

# %%
dataset_path='https://frenzy86.s3.eu-west-2.amazonaws.com/fav/iris.data'

df = pd.read_csv('https://frenzy86.s3.eu-west-2.amazonaws.com/fav/iris.data')

df.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

df
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_331e7 thead>tr>th {
#   text-align: left;
# }
# #T_331e7_row0_col0, #T_331e7_row1_col0, #T_331e7_row2_col0, #T_331e7_row3_col0, #T_331e7_row4_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_331e7_row0_col1, #T_331e7_row1_col1, #T_331e7_row2_col1, #T_331e7_row3_col1, #T_331e7_row4_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_331e7_row0_col2, #T_331e7_row1_col2, #T_331e7_row2_col2, #T_331e7_row3_col2, #T_331e7_row4_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_331e7_row0_col3, #T_331e7_row1_col3, #T_331e7_row2_col3, #T_331e7_row3_col3, #T_331e7_row4_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
# ...

# %%
sns.pairplot(df, hue = 'class')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# decreto le variabili
X = df[['sepal length', 'sepal widht', 'petal lenght', 'petal width']]
y = df['class']

# creo il df
X_test, X_pred, y_test, y_pred = train_test_split(X, y, size = 0.30, random_state=7)

#creo il modello
reg = linear_model.LogisticRegression()

# fitto il modello
reg.fit(X_train, y_train)

#faccio la prediction
y_pred = reg.predict(X_test)

#FINIRE IL MODELLO, CONTROLLARE L'ERRORE
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 # decreto le variabili
# ----> 2 X = df[['sepal length', 'sepal widht', 'petal lenght', 'petal width']]
#       3 y = df['class']
#       5 # creo il df
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
