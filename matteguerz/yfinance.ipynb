# %%
# !pip install yfinance

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

import datetime

# %%
nvda = yf.Ticker("NVDA")
tsla = yf.Ticker("TSLA")
appl = yf.Ticker("AAPL")

# %% [markdown]
# ## NVDA DF

# %%
df_nvda = pd.DataFrame(nvda.history(start = "2000-01-01", end = "2025-01-21", actions = False))
df_nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2000-01-03 00:00:00-05:00    0.090276    0.090992    0.084305    0.089440
# 2000-01-04 00:00:00-05:00    0.087887    0.088126    0.082633    0.087052
# 2000-01-05 00:00:00-05:00    0.084544    0.085977    0.082992    0.084186
# 2000-01-06 00:00:00-05:00    0.084186    0.084186    0.075469    0.078692
# 2000-01-07 00:00:00-05:00    0.078335    0.080842    0.077141    0.080007
# ...                               ...         ...         ...         ...
# 2025-01-13 00:00:00-05:00  129.990005  133.490005  129.509995  133.229996
# 2025-01-14 00:00:00-05:00  136.050003  136.380005  130.050003  131.759995
# 2025-01-15 00:00:00-05:00  133.649994  136.449997  131.289993  136.240005
# 2025-01-16 00:00:00-05:00  138.639999  138.750000  133.490005  133.570007
# 2025-01-17 00:00:00-05:00  136.690002  138.500000  135.460007  137.710007
#
#                               Volume
# Date
# ...

# %%
title = 'Yearly Mean Closing Price for NVDA'
df_nvda['Close'].resample('Y').mean().plot(title = title,
                                           figsize=(10, 6),
                                           color = 'blue');
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_25592\4032305061.py:2: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_nvda['Close'].resample('Y').mean().plot(title = title,

# %%
title = 'Monthly Mean Closing Price for NVDA (2024)'
df_nvda['Close']['2024'].resample('M').mean().plot.bar(title = title,
                                           figsize=(10, 6),
                                           color = 'red');
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_25592\2762935289.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_nvda['Close']['2024'].resample('M').mean().plot.bar(title = title,

# %% [markdown]
# ## TSLA DF

# %%
df_tsla = pd.DataFrame(tsla.history(start = "2000-01-01", end = "2025-01-21", actions = False))
df_tsla
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2025-01-13 00:00:00-05:00  383.209991  403.790009  380.070007  403.309998
# 2025-01-14 00:00:00-05:00  414.339996  422.640015  394.540009  396.359985
# 2025-01-15 00:00:00-05:00  409.899994  429.799988  405.660004  428.220001
# 2025-01-16 00:00:00-05:00  423.489990  424.000000  409.130005  413.820007
# 2025-01-17 00:00:00-05:00  421.500000  439.739990  419.750000  426.500000
#
#                               Volume
# Date
# ...

# %%
title = '2024 monhtly mean Closing Price for TSLA'
df_tsla['Close']['2024'].resample('M').mean().plot.bar(title = title,
                                           figsize=(10, 6),
                                           color = 'green');
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_25592\1600731528.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tsla['Close']['2024'].resample('M').mean().plot.bar(title = title,
