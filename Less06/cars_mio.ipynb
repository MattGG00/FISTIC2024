# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/cars.csv
path = 'https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/cars.csv'

df = pd.read_csv(path)
df
# Out:
#                                        name  year          Price  kms_driven  \
# 0      Hyundai Santro Xing XO eRLX Euro III  2007         80,000  45,000 kms
# 1                   Mahindra Jeep CL550 MDI  2006       4,25,000      40 kms
# 2                Maruti Suzuki Alto 800 Vxi  2018  Ask For Price  22,000 kms
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT  2014       3,25,000  28,000 kms
# 4          Ford EcoSport Titanium 1.5L TDCi  2014       5,75,000  36,000 kms
# ..                                      ...   ...            ...         ...
# 887                                      Ta  zest       3,10,000         NaN
# 888                     Tata Zest XM Diesel  2018       2,60,000  27,000 kms
# 889                      Mahindra Quanto C8  2013       3,90,000  40,000 kms
# 890                Honda Amaze 1.2 E i VTEC  2014       1,80,000      Petrol
# 891               Chevrolet Sail 1.2 LT ABS  2014       1,60,000      Petrol
#
#     fuel_type
# 0      Petrol
# ...

# %%
df['fuel_type'] = df['fuel_type'].fillna(df['fuel_type'].mode()[0])

# %%
df
# Out:
#                                        name  year          Price  kms_driven  \
# 0      Hyundai Santro Xing XO eRLX Euro III  2007         80,000  45,000 kms
# 1                   Mahindra Jeep CL550 MDI  2006       4,25,000      40 kms
# 2                Maruti Suzuki Alto 800 Vxi  2018  Ask For Price  22,000 kms
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT  2014       3,25,000  28,000 kms
# 4          Ford EcoSport Titanium 1.5L TDCi  2014       5,75,000  36,000 kms
# ..                                      ...   ...            ...         ...
# 887                                      Ta  zest       3,10,000         NaN
# 888                     Tata Zest XM Diesel  2018       2,60,000  27,000 kms
# 889                      Mahindra Quanto C8  2013       3,90,000  40,000 kms
# 890                Honda Amaze 1.2 E i VTEC  2014       1,80,000      Petrol
# 891               Chevrolet Sail 1.2 LT ABS  2014       1,60,000      Petrol
#
#     fuel_type
# 0      Petrol
# ...

# %%
df['kms_driven'] = df['kms_driven'].str.replace('kms', '').str.replace('Petrol', '').str.replace(',', '')

# %%
df['kms_driven'] = pd.to_numeric(df['kms_driven'], errors='coerce')         # 2. Conversione in numeri

df['kms_driven'] = df['kms_driven'].fillna(df['kms_driven'].median())       # 3. fill NaN

# %%
df['name'].values
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV',
#        'Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Audi A8', 'Audi Q7', 'Mahindra Scorpio S10',
#        'Maruti Suzuki Alto 800', 'Mahindra Scorpio S10',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai i20 Sportz 1.2', 'Hyundai i20 Sportz 1.2',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
# ...

# %%
df['Price'].describe()
# Out:
# count               892
# unique              274
# top       Ask For Price
# freq                 35
# Name: Price, dtype: object
